# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies=pd.read_csv("../data/tmdb_5000_movies.csv")
credits=pd.read_csv("../data/tmdb_5000_credits.csv")

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   str
#  2   homepage              1712 non-null   str
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   str
#  5   original_language     4803 non-null   str
#  6   original_title        4803 non-null   str
#  7   overview              4800 non-null   str
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   str
#  10  production_countries  4803 non-null   str
#  11  release_date          4802 non-null   str
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   str
# ...

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
#let's try to understand what the columns are telling us 
#budget: obv, the amount of money that went into making the movie , but currency is not given ,assuming it's USD
#genres: the type of film it is , but the data stored in the column isn't fully visible, 
#homepage: the homepage of the website of the film 
#id : might be the primary key of this dataset
#keywords: can't tell anything about it 
#original language: the language it was made in 
#original title: the title the movie was initally given 
#overview: the summary or the snippet of the movie
#popularity : Popularity appears to be an engagement metric rather than a semantic similarity feature.
#production_companies: the comapanies that put money into making thse films, i'm not able to understand the way data is stored here
#production_countries: the country to which the companies belong?
#release_date: the day the movie was released 
#revenue: the money the movie earned 
#runtime: the dureation of the movie
#spoken_languages: the languages the movie was shown in ?
#status: whether the movie is  released or not , whether it's banned ? 
#tagline: the line that sums up the movie 
#title: the title with which the movie was released worldwide
#vote_average: i don't know what this means
#vote_count: what do these votes mean ? who voted here?

# %%
df.head()
# Out:
#         budget                                             genres  \
# 97    15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 215  130000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 235   97250400  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 317   94000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 474          0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
#
#                                               homepage      id  \
# 97                                                 NaN  315011
# 215                                                NaN    1979
# 235  http://www.asterixauxjeuxolympiques.com/index.php    2395
# 317               http://www.theflowersofwarmovie.com/   76758
# 474                                                NaN  330770
#
#                                               keywords original_language  \
# 97   [{"id": 1299, "name": "monster"}, {"id": 7671,...                ja
# ...

# %%
#let's checkout the null values
(movies.isnull().sum()/movies.shape[0])*100
# Out:
# budget                   0.000000
# genres                   0.000000
# homepage                64.355611
# id                       0.000000
# keywords                 0.000000
# original_language        0.000000
# original_title           0.000000
# overview                 0.062461
# popularity               0.000000
# production_companies     0.000000
# production_countries     0.000000
# release_date             0.020820
# revenue                  0.000000
# runtime                  0.041641
# spoken_languages         0.000000
# status                   0.000000
# tagline                 17.572351
# title                    0.000000
# vote_average             0.000000
# vote_count               0.000000
# dtype: float64

# %%
#based on the percentage of null or missing values in each column, we cansay that we can remove the homepage column as more than 60%
#of the data is missing , and so there is no point of filling these spaces,
#otherwise the rest of the columns are negligibily empty, that is very less null values except the column of tagline , but the thing about a tagline is
#it's unique for a  movie , so i'm not sure sure how exactly i'm gonna fill that column

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   str
#  2   homepage              1712 non-null   str
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   str
#  5   original_language     4803 non-null   str
#  6   original_title        4803 non-null   str
#  7   overview              4800 non-null   str
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   str
#  10  production_countries  4803 non-null   str
#  11  release_date          4802 non-null   str
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   str
# ...

# %%
credits.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   str
#  2   cast      4803 non-null   str
#  3   crew      4803 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 150.2 KB

# %%
credits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
#let's check null values here
(credits.isnull().sum()/credits.shape[0])*100
# Out:
# movie_id    0.0
# title       0.0
# cast        0.0
# crew        0.0
# dtype: float64

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='str')

# %%
#finalized columns of need
#from the  dataset credits
#all, movie_id, title, cast,crew
#from the dataset od movies
#genres,keywords
#now we need to visualise some of the columns

# %%
sns.set_style("darkgrid")
plt.hist(movies['runtime'],bins=20,color='cadetblue',edgecolor='black',alpha=0.7)
plt.title("Univariate analysis of the runtime")
plt.xlabel("Runtime in mins")
plt.ylabel("Count")
plt.show()
